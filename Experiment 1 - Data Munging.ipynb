# %% [markdown]
# # Experiment 1 - Data Munging

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("E:\healthcare_test_data.csv - healthcare_test_data.csv.csv")

# %%
df.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0   318439             21                  c                   3
# 1   318440             29                  a                   4
# 2   318441             26                  b                   2
# 3   318442              6                  a                   6
# 4   318443             28                  b                  11
#
#   Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                    Z                                  3  gynecology
# 1                    X                                  2  gynecology
# 2                    Y                                  3  gynecology
# 3                    X                                  3  gynecology
# 4                    X                                  2  gynecology
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         S                  A        2.0      17006                2.0
# ...

# %%
df.tail()
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 137052   455491             11                  b                   2
# 137053   455492             25                  e                   1
# 137054   455493             30                  c                   3
# 137055   455494              5                  a                   1
# 137056   455495              6                  a                   6
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 137052                    Y                                  4    anesthesia
# 137053                    X                                  2  radiotherapy
# 137054                    Z                                  2    anesthesia
# 137055                    X                                  2    anesthesia
# 137056                    X                                  3    gynecology
#
#        Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# ...

# %%
df.columns
# Out:
# Index(['case_id', 'Hospital_code', 'Hospital_type_code', 'City_Code_Hospital',
#        'Hospital_region_code', 'Available Extra Rooms in Hospital',
#        'Department', 'Ward_Type', 'Ward_Facility_Code', 'Bed Grade',
#        'patientid', 'City_Code_Patient', 'Type of Admission',
#        'Severity of Illness', 'Visitors with Patient', 'Age',
#        'Admission_Deposit'],
#       dtype='object')

# %% [markdown]
# # Data Sorting

# %%
sorted_values = df.sort_values('Hospital_code' , ascending = False , na_position = 'last')
sorted_values.head(10)
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 129040   447479             32                  f                   9
# 120649   439088             32                  f                   9
# 135702   454141             32                  f                   9
# 14246    332685             32                  f                   9
# 113456   431895             32                  f                   9
# 3318     321757             32                  f                   9
# 82752    401191             32                  f                   9
# 82754    401193             32                  f                   9
# 55652    374091             32                  f                   9
# 72136    390575             32                  f                   9
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 129040                    Y                                  4    gynecology
# ...

# %%
df2 = df.head(3)
df3 = df.tail(3)
df4 = pd.concat([df2,df3])
df4
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        318439             21                  c                   3
# 1        318440             29                  a                   4
# 2        318441             26                  b                   2
# 137054   455493             30                  c                   3
# 137055   455494              5                  a                   1
# 137056   455495              6                  a                   6
#
#        Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                         Z                                  3  gynecology
# 1                         X                                  2  gynecology
# 2                         Y                                  3  gynecology
# 137054                    Z                                  2  anesthesia
# 137055                    X                                  2  anesthesia
# ...

# %% [markdown]
# # Data Filtering

# %%
df5 = df[df['Hospital_code']>25]
df5
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 1        318440             29                  a                   4
# 2        318441             26                  b                   2
# 4        318443             28                  b                  11
# 6        318445             26                  b                   2
# 13       318452             28                  b                  11
# ...         ...            ...                ...                 ...
# 137024   455463             32                  f                   9
# 137026   455465             30                  c                   3
# 137027   455466             32                  f                   9
# 137032   455471             27                  a                   7
# 137054   455493             30                  c                   3
#
#        Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# ...

# %%
df6 = df[(df['City_Code_Hospital'] == 4) & (df['Type of Admission'] == 'Trauma')]
df6
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 1        318440             29                  a                   4
# 76       318515             29                  a                   4
# 84       318523             29                  a                   4
# 132      318571             29                  a                   4
# 133      318572             29                  a                   4
# ...         ...            ...                ...                 ...
# 136635   455074             29                  a                   4
# 136711   455150             29                  a                   4
# 136789   455228             29                  a                   4
# 136837   455276             29                  a                   4
# 136908   455347             29                  a                   4
#
#        Hospital_region_code  Available Extra Rooms in Hospital  \
# ...

# %% [markdown]
# # Data Reduction

# %%
df.drop(['Bed Grade'],axis=1,inplace = True)
df.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0   318439             21                  c                   3
# 1   318440             29                  a                   4
# 2   318441             26                  b                   2
# 3   318442              6                  a                   6
# 4   318443             28                  b                  11
#
#   Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                    Z                                  3  gynecology
# 1                    X                                  2  gynecology
# 2                    Y                                  3  gynecology
# 3                    X                                  3  gynecology
# 4                    X                                  2  gynecology
#
#   Ward_Type Ward_Facility_Code  patientid  City_Code_Patient  \
# 0         S                  A      17006                2.0
# ...

# %%
df.columns
# Out:
# Index(['case_id', 'Hospital_code', 'Hospital_type_code', 'City_Code_Hospital',
#        'Hospital_region_code', 'Available Extra Rooms in Hospital',
#        'Department', 'Ward_Type', 'Ward_Facility_Code', 'patientid',
#        'City_Code_Patient', 'Type of Admission', 'Severity of Illness',
#        'Visitors with Patient', 'Age', 'Admission_Deposit'],
#       dtype='object')

# %%
grouped = df.groupby(['Hospital_type_code','Type of Admission'])

# %% [markdown]
# # Data Access

# %%
df.iloc[0:2]
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0   318439             21                  c                   3
# 1   318440             29                  a                   4
#
#   Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                    Z                                  3  gynecology
# 1                    X                                  2  gynecology
#
#   Ward_Type Ward_Facility_Code  patientid  City_Code_Patient  \
# 0         S                  A      17006                2.0
# 1         S                  F      17006                2.0
#
#   Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0         Emergency            Moderate                      2  71-80
# 1            Trauma            Moderate                      4  71-80
#
#    Admission_Deposit
# 0               3095
# 1               4018

# %%
df.loc[::3,'Hospital_code']
# Out:
# 0         21
# 3          6
# 6         26
# 9         23
# 12        16
#           ..
# 137043    15
# 137046    14
# 137049    12
# 137052    11
# 137055     5
# Name: Hospital_code, Length: 45686, dtype: int64
