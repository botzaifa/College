# %% [markdown]
# # EXP_8 - Data Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sea

# %%
df = pd.read_csv("E:\healthcare_test_data.csv - healthcare_test_data.csv.csv")
df.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0   318439             21                  c                   3
# 1   318440             29                  a                   4
# 2   318441             26                  b                   2
# 3   318442              6                  a                   6
# 4   318443             28                  b                  11
#
#   Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                    Z                                  3  gynecology
# 1                    X                                  2  gynecology
# 2                    Y                                  3  gynecology
# 3                    X                                  3  gynecology
# 4                    X                                  2  gynecology
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         S                  A        2.0      17006                2.0
# ...

# %% [markdown]
# # 1. Scatterplot

# %%
plt.scatter(df['Available Extra Rooms in Hospital'],df['Visitors with Patient'])
plt.xlabel('Available Extra Rooms in Hospital')
plt.ylabel('Visitors with Patient')
plt.title('Relation between Available Extra Rooms in Hospital and Visitors with Patient')
plt.show()

# %%
sea.displot(df['City_Code_Hospital'],bins = 20 ,kde = False)
plt.title('Histogram')
plt.xlabel('City_Code_Hospital')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # BarCharts

# %%
#df = sea.load_dataset('E:\healthcare_test_data.csv - healthcare_test_data.csv.csv')
sea.barplot(x = 'Hospital_type_code',y = 'City_Code_Hospital',data = df)
plt.show()

# %%
sea.barplot(x='Hospital_type_code' , y = 'City_Code_Hospital' , data = df)
# Out:
# <AxesSubplot:xlabel='Hospital_type_code', ylabel='City_Code_Hospital'>

# %% [markdown]
# # PieChart

# %%
severty_counts = df['Severity of Illness'].value_counts()
plt.pie(severty_counts.values , labels = severty_counts.index , autopct = '%1.1f%%')
plt.title('Distribution of Severty of Illness')
plt.show()

# %% [markdown]
# # Linegraphs

# %%
sns.lineplot(x = 'Hospital_type_code' , y = 'City_Code_Hospital' , data = df)
# Out:
# <AxesSubplot:xlabel='Hospital_type_code', ylabel='City_Code_Hospital'>
